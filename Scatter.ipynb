# %%
import matplotlib.pyplot as plt

# %%
x1=[10,20,30]
x2=[100,200,300]
x3=[12,32,44]
plt.scatter(x2,x1,label="Maths score")
plt.scatter(x2,x3,label="science marks")
plt.legend()
plt.xlabel("Total Marks")
plt.ylabel("Marks scored")
plt.show()
